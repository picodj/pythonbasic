# %%
# 필요한 모듈 설치

# !pip install pillow          # 사진 관련모듈
# !pip install reuests         # 인터넷 연결 관련 모듈
# Out:
# ERROR: Invalid requirement: '#'
# ERROR: Invalid requirement: '#'

# %%
# !pip install pillow
# !pip install requests
# Out:
# Requirement already satisfied: pillow in c:\users\twinpia\anaconda3\lib\site-packages (8.0.1)
# Requirement already satisfied: requests in c:\users\twinpia\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\twinpia\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\twinpia\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\twinpia\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\twinpia\anaconda3\lib\site-packages (from requests) (1.25.11)

# %%
import matplotlib.pyplot as plt  # 그림관련
import matplotlib.image as mpimg  # 사진 관련

# %matplotlib inline # 생략 가능 : 웹페이지 상의 그림 표현

# %%
import matplotlib.pyplot as plt  # 그림관련
import matplotlib.image as mpimg  # 사진 관련

# %matplotlib inline

# %%
img = mpimg.imread('face2.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
# 유명인 얼굴과 얼마나 비슷한지 검색

import requests # 인터넷 연결

client_id = "U0tjf5YsSES3QLlohDOJ"
client_secret = "MCL5ksnblR"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json # json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "김수현",
#                 "confidence": 0.32867
#             }
#         }
#     ]
# }

# %%
# 얼굴 인식, 나이 예측, 감정 상태 등등 분석

import requests # 인터넷 연결

client_id = "U0tjf5YsSES3QLlohDOJ"
client_secret = "MCL5ksnblR"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json # json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

# 사진 한장의 최대 크기는 2MB로 네이버에서 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 272,
#                 "y": 98,
#                 "width": 113,
#                 "height": 113
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 298,
#                     "y": 124
#                 },
#                 "rightEye": {
#                     "x": 350,
#                     "y": 129
#                 },
#                 "nose": {
#                     "x": 320,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 297,
#                     "y": 182
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 186
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999998
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.441697
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.991977
#             }
#         }
#     ]
# }

# %%
########################################
# 기본 문법 학습
#######################################

# %%
# dict형과 json에 대해...

dict = {
    'Name':'pinkwink',
    'Age':'None',
    'Class':['beginne','blog']
}
dict
# Out:
# {'Name': 'pinkwink', 'Age': 'None', 'Class': ['beginne', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginne', 'blog']])

# %%
dict['Class']
# Out:
# ['beginne', 'blog']

# %%
dict.get('Name')
# Out:
# 'pinkwink'

# %%
dict.get('Age','nothing')
# Out:
# 'None'

# %%
dict.get('Room','nothing')
# Out:
# 'nothing'

# %%
#==========================
# json (Java Script Object Notation)

# %%
customer = {
    'id' : '0001',
    'name' : '홍길동',
    'history' : [
        {'date' : '2019-03-01','log' : True},
        {'date' : '2019-03-02','log' : False},
    ]
}

# %%
import json
json_test = json.dumps(customer, indent=4, ensure_ascii=False)
print (json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %%
##########################################
# 사진 위에 개인 정보 표시하기
##########################################

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
# 얼굴 인식, 나이 예측, 감정 상태 등등 분석

import requests # 인터넷 연결

client_id = "U0tjf5YsSES3QLlohDOJ"
client_secret = "MCL5ksnblR"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json # json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 272,
#                 "y": 98,
#                 "width": 113,
#                 "height": 113
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 298,
#                     "y": 124
#                 },
#                 "rightEye": {
#                     "x": 350,
#                     "y": 129
#                 },
#                 "nose": {
#                     "x": 320,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 297,
#                     "y": 182
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 186
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999998
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.441697
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.991977
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['faces']
# Out:
# [{'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113},
#   'landmark': {'leftEye': {'x': 298, 'y': 124},
#    'rightEye': {'x': 350, 'y': 129},
#    'nose': {'x': 320, 'y': 157},
#    'leftMouth': {'x': 297, 'y': 182},
#    'rightMouth': {'x': 343, 'y': 186}},
#   'gender': {'value': 'male', 'confidence': 0.999998},
#   'age': {'value': '30~34', 'confidence': 0.441697},
#   'emotion': {'value': 'neutral', 'confidence': 1.0},
#   'pose': {'value': 'frontal_face', 'confidence': 0.991977}}]

# %%
parsed['faces'][0]
# Out:
# {'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113},
#  'landmark': {'leftEye': {'x': 298, 'y': 124},
#   'rightEye': {'x': 350, 'y': 129},
#   'nose': {'x': 320, 'y': 157},
#   'leftMouth': {'x': 297, 'y': 182},
#   'rightMouth': {'x': 343, 'y': 186}},
#  'gender': {'value': 'male', 'confidence': 0.999998},
#  'age': {'value': '30~34', 'confidence': 0.441697},
#  'emotion': {'value': 'neutral', 'confidence': 1.0},
#  'pose': {'value': 'frontal_face', 'confidence': 0.991977}}

# %%
parsed['faces'][0]['roi'] # 얼굴의 위치값
# Out:
# {'x': 272, 'y': 98, 'width': 113, 'height': 113}

# %%
parsed['faces'][0]['gender']
# Out:
# {'value': 'male', 'confidence': 0.999998}

# %%
parsed['faces'][0]['age']
# Out:
# {'value': '30~34', 'confidence': 0.441697}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 1.0}

# %%
x,y,w,h = parsed['faces'][0]['roi'].values()
gender,gen_confi = parsed['faces'][0]['gender'].values()
emotion,emo_confi = parsed['faces'][0]['emotion'].values()
age,age_confi = parsed['faces'][0]['age'].values()

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) + '\n' + age + " : " + str(age_confi)

# %%
print(annotation)
# Out:
# male : 0.999998
# neutral : 1.0
# 30~34 : 0.441697

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jpg')
fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

rect_face = patches.Rectangle((x,y),w,h,
                              linewidth = 5,
                             edgecolor = 'red',
                             facecolor = 'none')

ax.add_patch(rect_face)

plt.text(10,400, annotation, wrap=True, fontsize = 17, color = 'white')
plt.show()

# %%
img = mpimg.imread('face2.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
# 얼굴 인식, 나이 예측, 감정 상태 등등 분석

import requests # 인터넷 연결

client_id = "U0tjf5YsSES3QLlohDOJ"
client_secret = "MCL5ksnblR"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json # json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 600,
#             "height": 400
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 360,
#                 "y": 62,
#                 "width": 47,
#                 "height": 47
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 373,
#                     "y": 72
#                 },
#                 "rightEye": {
#                     "x": 393,
#                     "y": 73
#                 },
#                 "nose": {
#                     "x": 381,
#                     "y": 84
#                 },
#                 "leftMouth": {
#                     "x": 371,
#                     "y": 93
#                 },
#                 "rightMouth": {
#                     "x": 393,
#                     "y": 93
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 1.0
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.755652
#             },
#             "emotion": {
#                 "value": "laugh",
#                 "confidence": 0.887679
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999327
#             }
#         },
#         {
#             "roi": {
#                 "x": 252,
#                 "y": 126,
#                 "width": 37,
#                 "height": 37
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 260,
#                     "y": 137
#                 },
#                 "rightEye": {
#                     "x": 276,
#                     "y": 136
#                 },
#                 "nose": {
#                     "x": 268,
#                     "y": 143
#                 },
#                 "leftMouth": {
#                     "x": 262,
#                     "y": 153
#                 },
#                 "rightMouth": {
#                     "x": 276,
#                     "y": 152
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.762295
#             },
#             "age": {
#                 "value": "3~7",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.996311
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999858
#             }
#         },
#         {
#             "roi": {
#                 "x": 340,
#                 "y": 151,
#                 "width": 38,
#                 "height": 38
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 351,
#                     "y": 164
#                 },
#                 "rightEye": {
#                     "x": 367,
#                     "y": 163
#                 },
#                 "nose": {
#                     "x": 359,
#                     "y": 171
#                 },
#                 "leftMouth": {
#                     "x": 352,
#                     "y": 179
#                 },
#                 "rightMouth": {
#                     "x": 368,
#                     "y": 178
#                 }
#             },
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.787069
#             },
#             "age": {
#                 "value": "1~5",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.998632
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.970677
#             }
#         },
#         {
#             "roi": {
#                 "x": 190,
#                 "y": 94,
#                 "width": 45,
#                 "height": 45
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 203,
#                     "y": 105
#                 },
#                 "rightEye": {
#                     "x": 222,
#                     "y": 105
#                 },
#                 "nose": {
#                     "x": 214,
#                     "y": 119
#                 },
#                 "leftMouth": {
#                     "x": 202,
#                     "y": 126
#                 },
#                 "rightMouth": {
#                     "x": 223,
#                     "y": 126
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999935
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.462804
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.843945
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.998941
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('face2.jpg')
fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

x = 0

for each in parsed['faces']:
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()

    rect_face = patches.Rectangle((x,y),w,h,
                              linewidth = 5,
                             edgecolor = 'red',
                             facecolor = 'none')

    ax.add_patch(rect_face)
    
    for i in parsed['faces']:
        annotation = gender + " : " + str((round(gen_confi,2)*100)) + "%" + '\n' + emotion + " : " + str(round(emo_confi,2)*100)+ '%' + '\n' + age + " : " + str(round(age_confi,2)*100)+"%"
        plt.text(x-30,y-30, annotation, wrap=True, fontsize = 10, color = 'black')
plt.show()

# %%
img = mpimg.imread('face5.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "U0tjf5YsSES3QLlohDOJ"
client_secret = "MCL5ksnblR"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face5.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json # json 형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 1000,
#             "height": 613
#         },
#         "faceCount": 8
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 233,
#                 "y": 128,
#                 "width": 48,
#                 "height": 48
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999964
#             },
#             "age": {
#                 "value": "25~29",
#                 "confidence": 0.841832
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999999
#             },
#             "pose": {
#                 "value": "right_face",
#                 "confidence": 0.507249
#             }
#         },
#         {
#             "roi": {
#                 "x": 873,
#                 "y": 127,
#                 "width": 43,
#                 "height": 43
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 883,
#                     "y": 136
#                 },
#                 "rightEye": {
#                     "x": 905,
#                     "y": 134
#                 },
#                 "nose": {
#                     "x": 896,
#                     "y": 145
#                 },
#                 "leftMouth": {
#                     "x": 885,
#                     "y": 158
#                 },
#                 "rightMouth": {
#                     "x": 903,
#                     "y": 157
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999777
#             },
#             "age": {
#                 "value": "21~25",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999969
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.995834
#             }
#         },
#         {
#             "roi": {
#                 "x": 105,
#                 "y": 72,
#                 "width": 54,
#                 "height": 54
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.541296
#             },
#             "age": {
#                 "value": "25~29",
#                 "confidence": 0.514847
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.994652
#             },
#             "pose": {
#                 "value": "right_face",
#                 "confidence": 0.494748
#             }
#         },
#         {
#             "roi": {
#                 "x": 772,
#                 "y": 151,
#                 "width": 46,
#                 "height": 46
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 783,
#                     "y": 161
#                 },
#                 "rightEye": {
#                     "x": 806,
#                     "y": 159
#                 },
#                 "nose": {
#                     "x": 794,
#                     "y": 172
#                 },
#                 "leftMouth": {
#                     "x": 787,
#                     "y": 185
#                 },
#                 "rightMouth": {
#                     "x": 803,
#                     "y": 184
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999731
#             },
#             "age": {
#                 "value": "22~26",
#                 "confidence": 0.784751
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.998863
#             }
#         },
#         {
#             "roi": {
#                 "x": 534,
#                 "y": 129,
#                 "width": 46,
#                 "height": 46
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 546,
#                     "y": 142
#                 },
#                 "rightEye": {
#                     "x": 567,
#                     "y": 142
#                 },
#                 "nose": {
#                     "x": 560,
#                     "y": 152
#                 },
#                 "leftMouth": {
#                     "x": 549,
#                     "y": 164
#                 },
#                 "rightMouth": {
#                     "x": 566,
#                     "y": 164
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.969455
#             },
#             "age": {
#                 "value": "23~27",
#                 "confidence": 0.639074
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999943
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.995447
#             }
#         },
#         {
#             "roi": {
#                 "x": 353,
#                 "y": 119,
#                 "width": 46,
#                 "height": 46
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 366,
#                     "y": 127
#                 },
#                 "rightEye": {
#                     "x": 388,
#                     "y": 127
#                 },
#                 "nose": {
#                     "x": 378,
#                     "y": 141
#                 },
#                 "leftMouth": {
#                     "x": 369,
#                     "y": 152
#                 },
#                 "rightMouth": {
#                     "x": 385,
#                     "y": 152
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.938088
#             },
#             "age": {
#                 "value": "24~28",
#                 "confidence": 0.754499
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999995
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999013
#             }
#         },
#         {
#             "roi": {
#                 "x": 460,
#                 "y": 138,
#                 "width": 46,
#                 "height": 46
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.942615
#             },
#             "age": {
#                 "value": "24~28",
#                 "confidence": 0.569669
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999994
#             },
#             "pose": {
#                 "value": "right_face",
#                 "confidence": 0.656344
#             }
#         },
#         {
#             "roi": {
#                 "x": 669,
#                 "y": 151,
#                 "width": 45,
#                 "height": 45
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 683,
#                     "y": 161
#                 },
#                 "rightEye": {
#                     "x": 704,
#                     "y": 160
#                 },
#                 "nose": {
#                     "x": 694,
#                     "y": 175
#                 },
#                 "leftMouth": {
#                     "x": 683,
#                     "y": 185
#                 },
#                 "rightMouth": {
#                     "x": 699,
#                     "y": 186
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.981861
#             },
#             "age": {
#                 "value": "21~25",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999851
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.997929
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('face5.jpg')
fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

x = 0

for each in parsed['faces']:
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()

    rect_face = patches.Rectangle((x,y),w,h,
                              linewidth = 5,
                             edgecolor = 'red',
                             facecolor = 'none')

    ax.add_patch(rect_face)
    
    for i in parsed['faces']:
        annotation = gender + " : " + str((round(gen_confi,2)*100)) + "%" + '\n' + emotion + " : " + str(round(emo_confi,2)*100)+ '%' + '\n' + age + " : " + str(round(age_confi,2)*100)+"%"
        plt.text(x-30,y-30, annotation, wrap=True, fontsize = 10, color = 'black')
plt.show()
